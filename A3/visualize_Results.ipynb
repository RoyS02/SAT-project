# %% [markdown]
# # Results 20% k=0

# %%
import pandas as pd
df = pd.read_csv("20_results\k_0\CNF encoding\experiment_results.csv")
print(df)
# Out:
#     pair_index puzzle status  dpll_calls  num_vars  num_clauses   time_sec
# 0            1      A    SAT        1048       729        12850   2.257810
# 1            1      B    SAT         908       729        12850   1.914625
# 2            2      A    SAT       22550       729        12850  41.851630
# 3            2      B    SAT         391       729        12850   0.832487
# 4            3      A    SAT           1       729        12850   0.274350
# 5            3      B    SAT         149       729        12850   0.421490
# 6            4      A    SAT         833       729        12850   1.605213
# 7            4      B    SAT         774       729        12850   1.594670
# 8            5      A    SAT         154       729        12850   0.543101
# 9            5      B    SAT        3614       729        12850   6.933517
# 10           6      A    SAT           1       729        12850   0.272420
# ...
